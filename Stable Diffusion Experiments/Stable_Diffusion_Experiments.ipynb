# %% [markdown]
# ### Stable Diffusion Project
#
# ### By
# ### Daniyal Mufti
# ### Based on Hugging Face library
#
# https://colab.research.google.com/github/huggingface/notebooks/blob/main/diffusers/stable_diffusion.ipynb#scrollTo=zHkHsdtnry57

# %%
# !nvidia-smi
# !pip install diffusers==0.10.0
# !pip install transformers scipy ftfy accelerate
# !pip install "ipywidgets>=7,<8"
# Out:
# Fri Jan  6 04:21:28 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 517.48       Driver Version: 517.48       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:09:00.0  On |                  N/A |
# | 53%   29C    P8    52W / 390W |  21693MiB / 24576MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4860    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A      9364    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      9740    C+G   ...ekyb3d8bbwe\HxOutlook.exe    N/A      |
# |    0   N/A  N/A     10272    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10888    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     13336    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     13728    C+G   ...3d8bbwe\CalculatorApp.exe    N/A      |
# |    0   N/A  N/A     13840    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     13960    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     14768    C+G   ...in7x64\steamwebhelper.exe    N/A      |
# |    0   N/A  N/A     15292    C+G   ...perience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     15388      C   ...s\tensorflow25\python.exe    N/A      |
# |    0   N/A  N/A     17188    C+G   ...n64\EpicGamesLauncher.exe    N/A      |
# |    0   N/A  N/A     17296      C   ...s\tensorflow25\python.exe    N/A      |
# |    0   N/A  N/A     17332    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     17364    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     18668    C+G   ...s\Win64\EpicWebHelper.exe    N/A      |
# |    0   N/A  N/A     20580    C+G   ...ropbox\Client\Dropbox.exe    N/A      |
# |    0   N/A  N/A     21988    C+G   ...8wekyb3d8bbwe\GameBar.exe    N/A      |
# |    0   N/A  N/A     23076    C+G   ...ontend\Docker Desktop.exe    N/A      |
# |    0   N/A  N/A     25324    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# +-----------------------------------------------------------------------------+
# Requirement already satisfied: diffusers==0.10.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (0.10.0)
# Requirement already satisfied: huggingface-hub>=0.10.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from diffusers==0.10.0) (0.11.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from diffusers==0.10.0) (2022.10.31)
# Requirement already satisfied: numpy in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from diffusers==0.10.0) (1.22.4)
# Requirement already satisfied: requests in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from diffusers==0.10.0) (2.28.1)
# Requirement already satisfied: importlib-metadata in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from diffusers==0.10.0) (5.2.0)
# Requirement already satisfied: Pillow in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from diffusers==0.10.0) (9.2.0)
# Requirement already satisfied: filelock in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from diffusers==0.10.0) (3.9.0)
# Requirement already satisfied: tqdm in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0) (4.4.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0) (22.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from importlib-metadata->diffusers==0.10.0) (3.11.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->diffusers==0.10.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->diffusers==0.10.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->diffusers==0.10.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->diffusers==0.10.0) (1.26.13)
# Requirement already satisfied: colorama in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from tqdm->huggingface-hub>=0.10.0->diffusers==0.10.0) (0.4.5)
# Requirement already satisfied: transformers in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (4.25.1)
# Requirement already satisfied: scipy in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (1.6.2)
# Requirement already satisfied: ftfy in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (6.1.1)
# Requirement already satisfied: accelerate in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (0.15.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: filelock in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (0.11.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ftfy) (0.2.5)
# Requirement already satisfied: torch>=1.4.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from accelerate) (1.13.1)
# Requirement already satisfied: psutil in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from tqdm>=4.27->transformers) (0.4.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from requests->transformers) (1.26.13)
# Requirement already satisfied: ipywidgets<8,>=7 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (7.7.2)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipywidgets<8,>=7) (1.1.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipywidgets<8,>=7) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipywidgets<8,>=7) (7.31.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipywidgets<8,>=7) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipywidgets<8,>=7) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipywidgets<8,>=7) (6.15.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (23.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (0.1.6)
# Requirement already satisfied: psutil in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (5.9.0)
# Requirement already satisfied: packaging in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (22.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (7.4.7)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (3.0.20)
# Requirement already satisfied: decorator in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (5.1.1)
# Requirement already satisfied: pygments in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (2.11.2)
# Requirement already satisfied: colorama in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (0.7.5)
# Requirement already satisfied: backcall in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (65.6.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (6.4.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7) (4.11.2)
# Requirement already satisfied: entrypoints in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7) (0.4)
# Requirement already satisfied: jinja2 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (21.3.0)
# Requirement already satisfied: nbconvert in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (6.5.4)
# Requirement already satisfied: prometheus-client in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.14.1)
# Requirement already satisfied: nbformat in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (5.7.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7) (0.2.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7) (227)
# Requirement already satisfied: six>=1.5 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (2.1.1)
# Requirement already satisfied: bleach in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.8.4)
# Requirement already satisfied: lxml in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.5.13)
# Requirement already satisfied: tinycss2 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (1.2.1)
# Requirement already satisfied: defusedxml in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.7.1)
# Requirement already satisfied: fastjsonschema in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (4.16.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\daniy\anaconda3\envs\tensorflow25\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7) (3.11.0)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (manager).
# Your token has been saved to C:\Users\Daniy\.huggingface\token
# Login successful

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline
from PIL import Image, ImageDraw
import cv2
from IPython.display import display
import torch
torch.cuda.is_available()
# Out:
# True

# %%
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]

# %%
device = 'cuda'
pipe = pipe.to(device)

prompt = 'Vergil, photo realistic'
with autocast(device):
  image = pipe(prompt)[0]
print(image)
display(image[0])
  #print(pipe(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# [<PIL.Image.Image image mode=RGB size=512x512 at 0x1EC84E48310>]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### Try with higher inference steps

# %%
for i in range(3):
    prompt = 'Dyson Sphere in space'
    with autocast(device):
      image = pipe(prompt, num_inference_steps=250)[0]
      display(image[0])
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
#   0%|          | 0/250 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
#   0%|          | 0/250 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
